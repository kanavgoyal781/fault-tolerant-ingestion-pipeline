# %%
import json
import logging
import csv
import re
from bs4 import BeautifulSoup
from datetime import datetime, timezone
from typing import Optional, Dict, Any, List
from pydantic import BaseModel, Field, ValidationError

class MetadataModel(BaseModel):
    # optional fields
    title: str | None = None
    url: str
    external_id: str
    publish_date: str | None = None
    datetime: str | None = None
    first_publish_date: str | None = None
    website: str | None = None
    sections: list[str] = Field(default_factory=list)
    categories: list[str] = Field(default_factory=list)
    tags: list[str] = Field(default_factory=list)
    thumb: str | None = None

    # list fields


class QdrantDocument(BaseModel):
    text: str
    metadata: MetadataModel

import json
import logging
import csv
import re
from bs4 import BeautifulSoup
from datetime import datetime, timezone
from typing import Optional, Dict, Any, List

# --- 1. SETUP LOGGING ---
# This logger captures the "story" of each document
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.FileHandler("output/pipeline.log", mode='w', encoding='utf-8'), # 'w' overwrites log each run
        logging.StreamHandler()
    ]
)
logger = logging.getLogger("CapitolPipeline")

class DataTransformer:
    def __init__(self):
        # We can track state here if needed (e.g. total processed count)
        pass
        

    def clean_text(self, raw_string):
        if raw_string is None:
            return ""
        
        # Defensive Coding
        if not isinstance(raw_string, str):
            raw_string = str(raw_string)
    
        # CHANGE HERE: Use \n separator to preserve paragraph structure
        # and strip=True to remove leading/trailing whitespace from each block
        soup = BeautifulSoup(raw_string, "html.parser")
        text = soup.get_text(separator="\n")
        
        return text

    def clean_html_old(self, raw_html):
        """Helper: Removes HTML tags and returns clean text."""
        if not raw_html:
            return ""
        soup = BeautifulSoup(raw_html, "html.parser")

        text = soup.get_text(separator="\n")
        return text

    def clean_html(self, raw_html):
        """Helper: Removes HTML tags and returns clean text."""
        if not raw_html:
            return "", False
        soup = BeautifulSoup(raw_html, "html.parser")

        tags_found = [tag.name for tag in soup.find_all()]
        # if tags_found:
        #     print(f"DEBUG: Found HTML tags: {tags_found}")
        # else:
        #     print("DEBUG: No HTML tags found (Plain text).")
    
        text = soup.get_text(separator="\n", strip=True)
        return text, tags_found

    def get_text_body_old_working(self, raw_doc):
        """
        Loops through 'content_elements' to build the full article text.
        """
        text_parts = []
        elements = raw_doc.get('content_elements', [])
        
        for element in elements:
            el_type = element.get('type', '')
            
            # Case A: Standard Text or Headers
            if el_type in ['text']:
                content = element.get('content', '')
                if content:
                    text_parts.append(self.clean_html(content))
        
        # Join all parts with double newlines to separate paragraphs
        return " ".join(text_parts)

    def get_text_body_aj_test(self, raw_doc):
        """
        Loops through 'content_elements' to build the full article text.
        """
        text_parts = []
        elements = raw_doc.get('content_elements', [])

        full_text = ""
        is_prev_html = False
        
        for element in elements:
            el_type = element.get('type', '')
            
            # Case A: Standard Text or Headers
            if el_type in ['text']:
                content = element.get('content', '')
                if content:
                    # text_parts.append(self.clean_html(content))
                    cleaned_text, is_html = self.clean_html(content)
                    if is_html:
                        full_text = full_text + "\n" + cleaned_text.strip()
                        is_prev_html = True
                    elif is_prev_html:
                        full_text = full_text + "\n" + cleaned_text.strip()
                        is_prev_html = False
                    else:
                        full_text = full_text + " " + cleaned_text.strip()
        
        # Join all parts with double newlines to separate paragraphs
        # return " ".join(text_parts)
        return full_text

    def get_text_body(self, raw_doc):
        """
        Loops through 'content_elements' to build the full article text.
        """
        text_parts = []
        elements = raw_doc.get('content_elements', [])

        full_text = ""
        full_text_with_html = ""
        is_prev_html = False
        
        for element in elements:
            el_type = element.get('type', '')
            
            # Case A: Standard Text or Headers
            if el_type in ['text']:
                content = element.get('content', '')
                if content:
                    full_text_with_html = full_text_with_html + " " + content
                    full_text, is_html = self.clean_html(full_text_with_html)
        
        return full_text.strip()

    def extract_title(self, article):
        headlines = article.get("headlines")
        if not isinstance(headlines, dict):
            return ""
        raw_title = headlines.get("basic", "")
        return self.clean_text(raw_title)

    def extract_url_general(self, raw_doc: dict) -> str:
        """
        Build a clean URL from the raw doc.
    
        Rules:
        - If `website_url` is a relative path and `canonical_website` is present,
          build: https://www.{canonical_website}.com{website_url}
        - If `website_url` is already a full URL, return it as-is.
        - Otherwise, if `canonical_url` is a full URL, use that.
        - If nothing valid is found, return "" so the caller can treat it as missing.
        """
        raw_relative = raw_doc.get("website_url")
        raw_canonical = raw_doc.get("canonical_url")
        site_id = raw_doc.get("canonical_website")
    
        # Normalize strings safely
        def norm(s: Any) -> str:
            if not isinstance(s, str):
                return ""
            return s.strip()
    
        relative_path = norm(raw_relative)
        canonical_url = norm(raw_canonical)
    
        # 1) If we have a site_id and a relative path starting with '/', build absolute URL
        if isinstance(site_id, str) and site_id.strip():
            site_id = site_id.strip()
            base_domain = f"https://www.{site_id}.com"
    
            if relative_path.startswith("/"):
                return base_domain + relative_path
    
            # If website_url is already a full URL, just use it
            if relative_path.startswith("http://") or relative_path.startswith("https://"):
                return relative_path
    
        # 2) No usable site_id or no relative path.
        #    Accept website_url if it looks like a full URL.
        if relative_path.startswith("http://") or relative_path.startswith("https://"):
            return relative_path
    
        # 3) Fallback: canonical_url, but ONLY if it looks like a proper URL
        if canonical_url.startswith("http://") or canonical_url.startswith("https://"):
            return canonical_url
    
        # 4) Nothing valid → treat as missing.
        return ""

    def extract_id(self, raw_doc):
        """
        Extracts the unique identifier (_id) from the raw document.
        """
        doc_id = raw_doc.get('_id')
        if doc_id is None:
            return None
        return str(doc_id)

    def format_date_iso(self, date_str: Any) -> Optional[str]:
            """
            Normalize to ISO 8601 UTC.
            """
            if not date_str or not isinstance(date_str, str) or date_str[-1] != "Z":
                return None
    
            try:
                return date_str
    
            except (ValueError, TypeError):
                return None

    def extract_publish_date(self, raw_doc):
        # Try root level first, then additional_properties
        date_str = raw_doc.get('publish_date')
        return self.format_date_iso(date_str)

    def extract_first_publish_date(self, raw_doc):
        date_str = raw_doc.get('first_publish_date')
        return self.format_date_iso(date_str)

    def extract_datetime(self, raw_doc):
        """
        Logic: Prioritize 'last_updated_date' to represent current state.
        If missing, fallback to 'publish_date'.
        """
        update_str = raw_doc.get('last_updated_date')
        formatted = self.format_date_iso(update_str)
        if formatted:
            return formatted
        return self.extract_publish_date(raw_doc)

    def extract_website(self, raw_doc):
        # 'canonical_website' is the authoritative field in the raw data
        site = raw_doc.get('canonical_website')
        return str(site) if site else None

    def extract_sections(self, raw_doc):
        """
        Extracts the list of section names from the document's taxonomy.
        """
        taxonomy = raw_doc.get('taxonomy', {})
        if not taxonomy:
            return []

        raw_sections = taxonomy.get('sections', [])
        
        if not isinstance(raw_sections, list):
            return []
        
        section_names = []
        for section in raw_sections:
            if isinstance(section, dict):
                name = section.get('name')
                if name and isinstance(name, str):
                    section_names.append(name.strip())
                    
        return list(dict.fromkeys(section_names))

    def extract_categories(self, raw_doc):
        taxonomy = raw_doc.get('taxonomy', {})
        if not taxonomy:
            return []

        raw_categories = taxonomy.get('categories', [])
        if not isinstance(raw_categories, list):
            return []

        iab_cats = [
            c for c in raw_categories
            if isinstance(c, dict) and c.get('classifier') == 'iab_content_taxonomy'
        ]

        iab_cats.sort(key=lambda x: x.get('score', 0) or 0, reverse=True)

        final_categories = []
        seen = set()

        for cat in iab_cats:
            name = cat.get('name')
            if not name:
                continue

            cleaned = self.clean_text(name)
            if cleaned in seen:
                continue 

            seen.add(cleaned)
            final_categories.append(cleaned)

            if len(final_categories) == 5:
                break

        return final_categories

    def extract_tags(self, raw_doc):
        """
        Extracts tags for metadata.tags.
        """
        taxonomy = raw_doc.get("taxonomy", {})
        if not isinstance(taxonomy, dict):
            return []

        raw_tags = taxonomy.get("tags", [])
        if not isinstance(raw_tags, list):
            return []

        tags = []
        seen = set()

        for tag in raw_tags:
            if not isinstance(tag, dict):
                continue

            slug = tag.get("slug")
            if not isinstance(slug, str):
                continue

            slug = slug.strip()
            if not slug or slug in seen:
                continue

            seen.add(slug)
            tags.append(slug)

            if len(tags) == 5:
                break

        return tags

    def extract_thumb(self, raw_doc):
        """
        Extracts metadata.thumb (optional).
        Converts relative resizeUrl to absolute URL.
        """
        promo_items = raw_doc.get("promo_items") or {}
        if not isinstance(promo_items, dict): return None

        basic = promo_items.get("basic")
        if not isinstance(basic, dict): return None

        add_props = basic.get("additional_properties") or {}
        if not isinstance(add_props, dict): return None

        rel = add_props.get("resizeUrl")
        site = raw_doc.get("canonical_website")

        if isinstance(rel, str) and rel.strip() and isinstance(site, str) and site.strip():
            return f"https://www.{site.strip().lower()}.com{rel.strip()}"

        return None

    # --- MAIN PROCESSOR WITH DETAILED LOGGING ---
    # --- MAIN PROCESSOR WITH DETAILED LOGGING ---
    def process_document(self, raw_doc: dict) -> tuple[Optional[Dict], Dict]:
        """
        Orchestrates transformation with comprehensive logging for ALL fields.
        Returns: (Processed Document OR None, Report Dictionary)
        """
        if not isinstance(raw_doc, dict):
            logger.error(f"❌ SKIPPING: raw_doc is not a dict (got {type(raw_doc).__name__})")
            return None, {
                "id": "UNKNOWN_ID",
                "status": "SKIPPED",
                "reason": "Invalid document type (expected object)"
            }

        doc_id = raw_doc.get('_id', 'UNKNOWN_ID')
        report: Dict[str, Any] = {"id": doc_id, "status": "SKIPPED", "reason": "Unknown"}

        logger.info(f"📄 Processing Document ID: {doc_id}")

        # --- 1. CRITICAL CHECKS (Fail if missing) ---
        external_id = self.extract_id(raw_doc)
        if not external_id:
            logger.error("❌ SKIPPING: Document missing '_id'.")
            report["reason"] = "Missing ID"
            return None, report

        url = self.extract_url_general(raw_doc)
        if not url:
            logger.warning(f"   ⚠️ SKIPPING {doc_id}: Required field 'url' not found.")
            report["reason"] = "Missing URL"
            return None, report
        logger.info(f"   ✅ URL found: {url}")

        text_content = self.get_text_body(raw_doc)
        if not text_content or not text_content.strip():
            logger.warning(f"   ⚠️ SKIPPING {doc_id}: Required field 'text' is empty.")
            report["reason"] = "Missing Text"
            return None, report
        logger.info(f"   ✅ Text body found ({len(text_content)} chars).")

        # --- 2. OPTIONAL FIELD CHECKS (Log existence) ---
        title = self.extract_title(raw_doc)
        if title:
            logger.info(f"   ☑️ Title found: '{title[:30]}...'")
        else:
            logger.info("   ⚪ Title NOT found.")

        pub_date = self.extract_publish_date(raw_doc)
        if pub_date:
            logger.info(f"   ☑️ Publish Date found: {pub_date}")
        else:
            logger.info("   ⚪ Publish Date NOT found.")

        first_pub = self.extract_first_publish_date(raw_doc)
        if first_pub:
            logger.info(f"   ☑️ First Publish Date found: {first_pub}")
        else:
            logger.info("   ⚪ First Publish Date NOT found.")

        doc_time = self.extract_datetime(raw_doc)
        if doc_time:
            logger.info(f"   ☑️ Datetime found: {doc_time}")
        else:
            logger.info("   ⚪ Datetime NOT found.")

        website = self.extract_website(raw_doc)
        if website:
            logger.info(f"   ☑️ Website found: {website}")
        else:
            logger.info("   ⚪ Website NOT found.")

        thumb = self.extract_thumb(raw_doc)
        if thumb:
            logger.info("   ☑️ Thumbnail found.")
        else:
            logger.info("   ⚪ Thumbnail NOT found.")

        # Taxonomy lists
        sections = self.extract_sections(raw_doc)
        categories = self.extract_categories(raw_doc)
        tags = self.extract_tags(raw_doc)

        if sections:
            logger.info(f"   ☑️ Sections found: {len(sections)} items")
        else:
            logger.info("   ⚪ Sections empty.")

        if categories:
            logger.info(f"   ☑️ Categories found: {len(categories)} items")
        else:
            logger.info("   ⚪ Categories empty.")

        if tags:
            logger.info(f"   ☑️ Tags found: {len(tags)} items")
        else:
            logger.info("   ⚪ Tags empty.")

        # --- 3. BUILD METADATA ---
        try:
            # Build in the exact order you want to see in JSON
            metadata: Dict[str, Any] = {}

            # 1. Core identity
            if title:
                metadata["title"] = title
            metadata["url"] = url
            metadata["external_id"] = external_id

            # 2. Dates
            if pub_date:
                metadata["publish_date"] = pub_date
            if doc_time:
                metadata["datetime"] = doc_time
            if first_pub:
                metadata["first_publish_date"] = first_pub

            # 3. Source
            if website:
                metadata["website"] = website

            # 4. Taxonomy lists (always included, even if empty)
            metadata["sections"] = sections
            metadata["categories"] = categories
            metadata["tags"] = tags

            # 5. Media
            if thumb:
                metadata["thumb"] = thumb

            try:
                meta_model = MetadataModel(**metadata)
                doc_model = QdrantDocument(
                    text=text_content,
                    metadata=meta_model,
                )
            except ValidationError as ve:
                logger.error(f"   ❌ Validation failed for {doc_id}: {ve}")
                report["reason"] = "Schema validation failed"
                return None, report

            logger.info(f"   🎉 Document {doc_id} successfully transformed.")
            report["status"] = "SUCCESS"
            report["reason"] = ""

            # exclude_none=True ensures we don't output "title": null
            return doc_model.model_dump(exclude_none=True), report

        except Exception as e:
            logger.error(f"   💥 CRITICAL ERROR on {doc_id}: {e}")
            report["reason"] = f"Crash: {str(e)}"
            return None, report
dead_letter_path = "output/dead_letter_queue.jsonl"


def print_telemetry_dashboard(report_data):
    """
    Prints a simple reliability dashboard to the console.
    """
    total = len(report_data)
    if total == 0: return

    # 1. Calculate Metrics
    success = sum(1 for r in report_data if r['status'] == 'SUCCESS')
    failed = total - success
    success_rate = (success / total) * 100

    # 2. Group Failure Reasons
    failures = {}
    for r in report_data:
        if r['status'] != 'SUCCESS':
            reason = r.get('reason', 'Unknown')
            failures[reason] = failures.get(reason, 0) + 1

    # 3. Print The Dashboard
    print("\n" + "="*40)
    print(" 📊 PIPELINE HEALTH DASHBOARD")
    print("="*40)
    print(f" • Total Documents:   {total}")
    print(f" • Success Rate:      {success_rate:.1f}%")
    print(f" • Failed/Skipped:    {failed}")
    
    if failures:
        print("\n ⚠️  FAILURE BREAKDOWN (ROOT CAUSE)")
        print("-" * 40)
        # Sort by count (highest first)
        for reason, count in sorted(failures.items(), key=lambda x: x[1], reverse=True):
            print(f"   - {reason:<20} : {count} docs")
    print("="*40 + "\n")


# --- MAIN EXECUTION ---
if __name__ == "__main__":
    try:
        with open("data/raw_customer_api.json", "r", encoding="utf-8") as f:
            raw_data = json.load(f)
    except FileNotFoundError:
        print("❌ Error: 'raw_customer_api.json' not found.")
        exit(1)

    transformer = DataTransformer()
    
    # Key = external_id, Value = processed_doc
    # Using a dict ensures that if the same ID appears later, it overwrites the old one (Update).
    valid_docs_map = {}
    report_data = []

    print(f"🚀 Starting ingestion of {len(raw_data)} documents...")

    for doc in raw_data:
        # 1. Process EVERY document first
        processed_doc, report = transformer.process_document(doc)
        report_data.append(report)
        
        if processed_doc:
            # 2. Check for ID and handle Upsert (Update/Insert)
            ext_id = processed_doc.get('metadata', {}).get('external_id')
            if ext_id:
                if ext_id in valid_docs_map:
                    logger.info(f"   🔄 UPDATING: Overwriting existing record for ID {ext_id}")
                
                # This line handles both Insert (new key) and Update (overwrite value)
                valid_docs_map[ext_id] = processed_doc
        else:
            # 3. Handle Failures (Missing URL/ID/Text)
            doc_id = doc.get('_id', 'UNKNOWN')
            with open(dead_letter_path, "a", encoding="utf-8") as dl:
                record = {
                    "id": doc_id,
                    "reason": report.get("reason", "unknown"),
                    "raw_doc": doc,
                }
                dl.write(json.dumps(record, ensure_ascii=False) + "\n")

    # Convert map back to list for final JSON output
    valid_docs = list(valid_docs_map.values())

    # Save Valid Output (JSON)
    with open("output/processed_output_updated_2.json", "w", encoding="utf-8") as f:
        json.dump(valid_docs, f, indent=2, ensure_ascii=False)

    # Save Summary Report (CSV)
    with open("output/ingestion_report.csv", "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["id", "status", "reason"])
        writer.writeheader()
        writer.writerows(report_data)


    print_telemetry_dashboard(report_data)
    # Calculate Stats for Final Print
    total_input = len(raw_data)
    total_unique_output = len(valid_docs)
    total_failures = len([r for r in report_data if r['status'] != 'SUCCESS'])
    # Math: The missing count is the duplicates that were absorbed/merged
    total_merged = total_input - total_unique_output - total_failures

    print("\n✅ Processing Complete!")
    print(f"   - Total Input:      {total_input}")
    print(f"   - Unique Success:   {total_unique_output} (Saved to processed_output_updated.json)")
    print(f"   - Duplicates:       {total_merged} (Merged/Updated)")
    print(f"   - Failures:         {total_failures} (Sent to Dead Letter Queue)")
    print(f"   - Detailed Logs:    pipeline.log")
    print(f"   - Summary Report:   ingestion_report.csv")


def execute_transformation_step(input_file: str, output_file: str) -> List[Dict]:
    transformer = DataTransformer()
    try:
        with open(input_file, "r", encoding="utf-8") as f:
            raw_data = json.load(f)
    except FileNotFoundError:
        raise FileNotFoundError(f"Input file '{input_file}' not found.")
    
    valid_docs_map = {}
    
    for doc in raw_data:
        result, report = transformer.process_document(doc)
        
        if result: 
            ext_id = result.get('metadata', {}).get('external_id')
            if ext_id:
                valid_docs_map[ext_id] = result
    
    valid_docs = list(valid_docs_map.values())

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(valid_docs, f, indent=2, ensure_ascii=False)
    
    return valid_docs
# Out:
# 2025-12-23 20:39:07,798 [INFO] 📄 Processing Document ID: JTCFBWNDENCPFFOZPDK44JJEQA
# 2025-12-23 20:39:07,798 [INFO]    ✅ URL found: https://www.nj.com/advice/2025/07/miss-manners-i-tried-to-talk-to-her-but-she-said-id-rather-listen-to-what-the-men-are-talking-about.html
# 2025-12-23 20:39:07,799 [INFO]    ✅ Text body found (1678 chars).
# 2025-12-23 20:39:07,799 [INFO]    ☑️ Title found: 'Miss Manners: I tried to talk ...'
# 2025-12-23 20:39:07,799 [INFO]    ☑️ Publish Date found: 2025-07-02T00:00:00Z
# 2025-12-23 20:39:07,799 [INFO]    ☑️ First Publish Date found: 2025-07-02T00:00:00Z
# 2025-12-23 20:39:07,800 [INFO]    ☑️ Datetime found: 2025-07-02T00:00:37.341Z
# 2025-12-23 20:39:07,800 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,800 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,800 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,800 [INFO]    ⚪ Categories empty.
# 2025-12-23 20:39:07,800 [INFO]    ☑️ Tags found: 3 items
# 2025-12-23 20:39:07,800 [INFO]    🎉 Document JTCFBWNDENCPFFOZPDK44JJEQA successfully transformed.
# 2025-12-23 20:39:07,801 [INFO] 📄 Processing Document ID: RF36ELX6ZRERBCJBMKGA7HBWBU
# 2025-12-23 20:39:07,801 [INFO]    ✅ URL found: https://www.nj.com/shopping-deals/2025/07/forget-the-starbucks-line-amazon-can-get-you-a-ninja-slushi-to-diy-a-firework-frapp-ahead-of-july-4th.html
# 2025-12-23 20:39:07,802 [INFO]    ✅ Text body found (1570 chars).
# 2025-12-23 20:39:07,802 [INFO]    ☑️ Title found: 'Forget the Starbucks line — Am...'
# 2025-12-23 20:39:07,803 [INFO]    ☑️ Publish Date found: 2025-09-24T18:22:22.915Z
# 2025-12-23 20:39:07,803 [INFO]    ☑️ First Publish Date found: 2025-07-02T00:05:00Z
# 2025-12-23 20:39:07,803 [INFO]    ☑️ Datetime found: 2025-09-24T18:22:22.915Z
# 2025-12-23 20:39:07,803 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,803 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,803 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,804 [INFO]    ☑️ Categories found: 4 items
# 2025-12-23 20:39:07,804 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,804 [INFO]    🎉 Document RF36ELX6ZRERBCJBMKGA7HBWBU successfully transformed.
# 2025-12-23 20:39:07,804 [INFO] 📄 Processing Document ID: L6GN3MLTDVHJRMDF7ZBIBDXQHM
# 2025-12-23 20:39:07,804 [INFO]    ✅ URL found: https://www.nj.com/yankees/2025/07/yankees-lobby-for-rule-change-after-game-changing-catchers-interference-on-check-swing.html
# 2025-12-23 20:39:07,807 [INFO]    ✅ Text body found (3935 chars).
# 2025-12-23 20:39:07,807 [INFO]    ☑️ Title found: 'Yankees lobby for rule change ...'
# 2025-12-23 20:39:07,808 [INFO]    ☑️ Publish Date found: 2025-07-02T15:15:37.918Z
# 2025-12-23 20:39:07,808 [INFO]    ☑️ First Publish Date found: 2025-07-02T00:15:36.485Z
# 2025-12-23 20:39:07,808 [INFO]    ☑️ Datetime found: 2025-07-02T15:15:38.04Z
# 2025-12-23 20:39:07,808 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,809 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,809 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,809 [INFO]    ☑️ Categories found: 4 items
# 2025-12-23 20:39:07,810 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,810 [INFO]    🎉 Document L6GN3MLTDVHJRMDF7ZBIBDXQHM successfully transformed.
# 2025-12-23 20:39:07,810 [INFO] 📄 Processing Document ID: TOIFMZ2VDZGTPOGTYYOL3FAJ5M
# 2025-12-23 20:39:07,810 [INFO]    ✅ URL found: https://www.nj.com/weather-alerts/2025/07/flood-warning-in-place-for-monmouth-and-ocean-counties-until-1-a-m-wednesday-triggered-by-persistent.html
# 2025-12-23 20:39:07,813 [INFO]    ✅ Text body found (4931 chars).
# 2025-12-23 20:39:07,813 [INFO]    ☑️ Title found: 'Update: Monmouth and Ocean cou...'
# 2025-12-23 20:39:07,814 [INFO]    ☑️ Publish Date found: 2025-07-02T06:58:30.481Z
# 2025-12-23 20:39:07,814 [INFO]    ☑️ First Publish Date found: 2025-07-02T01:01:33.989Z
# 2025-12-23 20:39:07,814 [INFO]    ☑️ Datetime found: 2025-07-02T06:58:30.481Z
# 2025-12-23 20:39:07,814 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,815 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,815 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,815 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,816 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,816 [INFO]    🎉 Document TOIFMZ2VDZGTPOGTYYOL3FAJ5M successfully transformed.
# 2025-12-23 20:39:07,816 [INFO] 📄 Processing Document ID: T5H7Z6KVBFF3NGBBIFVOSHZOVM
# 2025-12-23 20:39:07,816 [INFO]    ✅ URL found: https://www.nj.com/advice/2025/07/todays-daily-horoscope-for-july-2-2025.html
# 2025-12-23 20:39:07,818 [INFO]    ✅ Text body found (5146 chars).
# 2025-12-23 20:39:07,818 [INFO]    ☑️ Title found: 'Today’s daily horoscope for Ju...'
# 2025-12-23 20:39:07,818 [INFO]    ☑️ Publish Date found: 2025-07-02T04:01:00Z
# 2025-12-23 20:39:07,818 [INFO]    ☑️ First Publish Date found: 2025-07-02T04:01:00Z
# 2025-12-23 20:39:07,819 [INFO]    ☑️ Datetime found: 2025-07-02T04:01:33.957Z
# 2025-12-23 20:39:07,819 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,819 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,819 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,820 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,820 [INFO]    ☑️ Tags found: 3 items
# 2025-12-23 20:39:07,820 [INFO]    🎉 Document T5H7Z6KVBFF3NGBBIFVOSHZOVM successfully transformed.
# 2025-12-23 20:39:07,820 [INFO] 📄 Processing Document ID: IRQOGWDD5JC2RF7AL6YQA23PRA
# 2025-12-23 20:39:07,820 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-homes-sold-in-parsippany-troy-hills-area-june-23-to-june-29.html
# 2025-12-23 20:39:07,820 [INFO]    ✅ Text body found (479 chars).
# 2025-12-23 20:39:07,820 [INFO]    ☑️ Title found: 'See homes sold in Parsippany-T...'
# 2025-12-23 20:39:07,821 [INFO]    ☑️ Publish Date found: 2025-07-02T04:58:01.854Z
# 2025-12-23 20:39:07,821 [INFO]    ☑️ First Publish Date found: 2025-07-02T04:58:01.854Z
# 2025-12-23 20:39:07,821 [INFO]    ☑️ Datetime found: 2025-07-02T04:58:21.338Z
# 2025-12-23 20:39:07,821 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,821 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,821 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,821 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,822 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,822 [INFO]    🎉 Document IRQOGWDD5JC2RF7AL6YQA23PRA successfully transformed.
# 2025-12-23 20:39:07,822 [INFO] 📄 Processing Document ID: PBUJKHAOKNFMBAG5Z4XDPIY7QI
# 2025-12-23 20:39:07,822 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-all-homes-sold-in-bloomfield-june-23-to-june-29.html
# 2025-12-23 20:39:07,822 [INFO]    ✅ Text body found (457 chars).
# 2025-12-23 20:39:07,823 [INFO]    ☑️ Title found: 'See all homes sold in Bloomfie...'
# 2025-12-23 20:39:07,823 [INFO]    ☑️ Publish Date found: 2025-07-02T05:08:01.862Z
# 2025-12-23 20:39:07,823 [INFO]    ☑️ First Publish Date found: 2025-07-02T05:08:01.862Z
# 2025-12-23 20:39:07,823 [INFO]    ☑️ Datetime found: 2025-07-02T05:08:21.334Z
# 2025-12-23 20:39:07,823 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,823 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,824 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,824 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,824 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,824 [INFO]    🎉 Document PBUJKHAOKNFMBAG5Z4XDPIY7QI successfully transformed.
# 2025-12-23 20:39:07,824 [INFO] 📄 Processing Document ID: ZEIGPW2YJZDTNERH5W3M2FKQ4A
# 2025-12-23 20:39:07,824 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-homes-sold-in-woodbridge-area-june-23-to-june-29.html
# 2025-12-23 20:39:07,824 [INFO]    ✅ Text body found (466 chars).
# 2025-12-23 20:39:07,825 [INFO]    ☑️ Title found: 'See homes sold in Woodbridge a...'
# 2025-12-23 20:39:07,825 [INFO]    ☑️ Publish Date found: 2025-07-02T05:18:01.769Z
# 2025-12-23 20:39:07,825 [INFO]    ☑️ First Publish Date found: 2025-07-02T05:18:01.769Z
# 2025-12-23 20:39:07,825 [INFO]    ☑️ Datetime found: 2025-07-02T05:18:20.88Z
# 2025-12-23 20:39:07,825 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,825 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,826 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,826 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,826 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,826 [INFO]    🎉 Document ZEIGPW2YJZDTNERH5W3M2FKQ4A successfully transformed.
# 2025-12-23 20:39:07,826 [INFO] 📄 Processing Document ID: OT6SFEP7RZBNHE4NDLRCVWOSOU
# 2025-12-23 20:39:07,827 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-all-homes-sold-in-east-brunswick-june-23-to-june-29.html
# 2025-12-23 20:39:07,827 [INFO]    ✅ Text body found (464 chars).
# 2025-12-23 20:39:07,827 [INFO]    ☑️ Title found: 'See all homes sold in East Bru...'
# 2025-12-23 20:39:07,827 [INFO]    ☑️ Publish Date found: 2025-07-02T05:18:06.796Z
# 2025-12-23 20:39:07,827 [INFO]    ☑️ First Publish Date found: 2025-07-02T05:18:06.796Z
# 2025-12-23 20:39:07,827 [INFO]    ☑️ Datetime found: 2025-07-02T05:18:25.754Z
# 2025-12-23 20:39:07,827 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,828 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,828 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,828 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,828 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,828 [INFO]    🎉 Document OT6SFEP7RZBNHE4NDLRCVWOSOU successfully transformed.
# 2025-12-23 20:39:07,828 [INFO] 📄 Processing Document ID: ULTEG77EKRBMJKCW7IVJRU5OUQ
# 2025-12-23 20:39:07,828 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-all-homes-sold-in-hillsborough-june-23-to-june-29.html
# 2025-12-23 20:39:07,829 [INFO]    ✅ Text body found (463 chars).
# 2025-12-23 20:39:07,829 [INFO]    ☑️ Title found: 'See all homes sold in Hillsbor...'
# 2025-12-23 20:39:07,829 [INFO]    ☑️ Publish Date found: 2025-07-02T05:18:11.737Z
# 2025-12-23 20:39:07,829 [INFO]    ☑️ First Publish Date found: 2025-07-02T05:18:11.737Z
# 2025-12-23 20:39:07,829 [INFO]    ☑️ Datetime found: 2025-07-02T05:18:30.482Z
# 2025-12-23 20:39:07,829 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,829 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,830 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,830 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,830 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,830 [INFO]    🎉 Document ULTEG77EKRBMJKCW7IVJRU5OUQ successfully transformed.
# 2025-12-23 20:39:07,830 [INFO] 📄 Processing Document ID: 5MUEHHA35NHSHKQV3KDIVLOYUA
# 2025-12-23 20:39:07,830 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-homes-sold-in-camden-area-june-23-to-june-29.html
# 2025-12-23 20:39:07,830 [INFO]    ✅ Text body found (458 chars).
# 2025-12-23 20:39:07,831 [INFO]    ☑️ Title found: 'See homes sold in Camden area,...'
# 2025-12-23 20:39:07,831 [INFO]    ☑️ Publish Date found: 2025-07-02T05:48:02.007Z
# 2025-12-23 20:39:07,831 [INFO]    ☑️ First Publish Date found: 2025-07-02T05:48:02.007Z
# 2025-12-23 20:39:07,831 [INFO]    ☑️ Datetime found: 2025-07-02T05:48:21.055Z
# 2025-12-23 20:39:07,832 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,832 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,832 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,833 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,833 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,833 [INFO]    🎉 Document 5MUEHHA35NHSHKQV3KDIVLOYUA successfully transformed.
# 2025-12-23 20:39:07,833 [INFO] 📄 Processing Document ID: QSKOJBN34NDEZJQUIGMPSKX42E
# 2025-12-23 20:39:07,833 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-homes-sold-in-east-orange-area-june-23-to-june-29.html
# 2025-12-23 20:39:07,834 [INFO]    ✅ Text body found (467 chars).
# 2025-12-23 20:39:07,834 [INFO]    ☑️ Title found: 'See homes sold in East Orange ...'
# 2025-12-23 20:39:07,834 [INFO]    ☑️ Publish Date found: 2025-07-02T05:48:06.99Z
# 2025-12-23 20:39:07,834 [INFO]    ☑️ First Publish Date found: 2025-07-02T05:48:06.99Z
# 2025-12-23 20:39:07,834 [INFO]    ☑️ Datetime found: 2025-07-02T05:48:25.927Z
# 2025-12-23 20:39:07,834 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,834 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,835 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,835 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,835 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,835 [INFO]    🎉 Document QSKOJBN34NDEZJQUIGMPSKX42E successfully transformed.
# 2025-12-23 20:39:07,835 [INFO] 📄 Processing Document ID: I7ZS4UWMVRFXZMDLJMQW7FNL5U
# 2025-12-23 20:39:07,835 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-all-homes-sold-in-linden-june-23-to-june-29.html
# 2025-12-23 20:39:07,835 [INFO]    ✅ Text body found (447 chars).
# 2025-12-23 20:39:07,836 [INFO]    ☑️ Title found: 'See all homes sold in Linden, ...'
# 2025-12-23 20:39:07,836 [INFO]    ☑️ Publish Date found: 2025-07-02T05:58:01.806Z
# 2025-12-23 20:39:07,836 [INFO]    ☑️ First Publish Date found: 2025-07-02T05:58:01.806Z
# 2025-12-23 20:39:07,836 [INFO]    ☑️ Datetime found: 2025-07-02T05:58:20.539Z
# 2025-12-23 20:39:07,836 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,836 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,837 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,837 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,837 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,837 [INFO]    🎉 Document I7ZS4UWMVRFXZMDLJMQW7FNL5U successfully transformed.
# 2025-12-23 20:39:07,837 [INFO] 📄 Processing Document ID: AP23FZGLGVDOLOBKINF3ILPBII
# 2025-12-23 20:39:07,837 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-all-homes-sold-in-berkeley-june-23-to-june-29.html
# 2025-12-23 20:39:07,838 [INFO]    ✅ Text body found (454 chars).
# 2025-12-23 20:39:07,838 [INFO]    ☑️ Title found: 'See all homes sold in Berkeley...'
# 2025-12-23 20:39:07,838 [INFO]    ☑️ Publish Date found: 2025-07-02T06:18:58.626Z
# 2025-12-23 20:39:07,838 [INFO]    ☑️ First Publish Date found: 2025-07-02T06:18:01.735Z
# 2025-12-23 20:39:07,838 [INFO]    ☑️ Datetime found: 2025-07-02T06:18:58.727Z
# 2025-12-23 20:39:07,838 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,839 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,839 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,839 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,839 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,839 [INFO]    🎉 Document AP23FZGLGVDOLOBKINF3ILPBII successfully transformed.
# 2025-12-23 20:39:07,839 [INFO] 📄 Processing Document ID: TLR3IXQ2CBHPDO7H52KQUDBQ5E
# 2025-12-23 20:39:07,840 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-homes-sold-in-plainfield-area-june-23-to-june-29.html
# 2025-12-23 20:39:07,840 [INFO]    ✅ Text body found (476 chars).
# 2025-12-23 20:39:07,840 [INFO]    ☑️ Title found: 'See homes sold in Plainfield a...'
# 2025-12-23 20:39:07,840 [INFO]    ☑️ Publish Date found: 2025-07-02T06:38:01.784Z
# 2025-12-23 20:39:07,840 [INFO]    ☑️ First Publish Date found: 2025-07-02T06:38:01.784Z
# 2025-12-23 20:39:07,840 [INFO]    ☑️ Datetime found: 2025-07-02T06:38:20.111Z
# 2025-12-23 20:39:07,840 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,840 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,841 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,841 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,841 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,841 [INFO]    🎉 Document TLR3IXQ2CBHPDO7H52KQUDBQ5E successfully transformed.
# 2025-12-23 20:39:07,841 [INFO] 📄 Processing Document ID: XCR5ZS34YBBPLJ4U2VIMSN5274
# 2025-12-23 20:39:07,841 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-all-homes-sold-in-west-orange-june-23-to-june-29.html
# 2025-12-23 20:39:07,842 [INFO]    ✅ Text body found (459 chars).
# 2025-12-23 20:39:07,842 [INFO]    ☑️ Title found: 'See all homes sold in West Ora...'
# 2025-12-23 20:39:07,842 [INFO]    ☑️ Publish Date found: 2025-07-02T06:48:01.787Z
# 2025-12-23 20:39:07,842 [INFO]    ☑️ First Publish Date found: 2025-07-02T06:48:01.787Z
# 2025-12-23 20:39:07,842 [INFO]    ☑️ Datetime found: 2025-07-02T06:48:20.758Z
# 2025-12-23 20:39:07,842 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,842 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,843 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,843 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,843 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,843 [INFO]    🎉 Document XCR5ZS34YBBPLJ4U2VIMSN5274 successfully transformed.
# 2025-12-23 20:39:07,843 [INFO] 📄 Processing Document ID: 3D7QNFCLPZDJNFQD7JWNZX7NH4
# 2025-12-23 20:39:07,843 [INFO]    ✅ URL found: https://www.nj.com/sports/2025/07/madison-keys-vs-olga-danilovic-7225-free-live-stream-watch-wimbledon-match-online-time-tv-channel.html
# 2025-12-23 20:39:07,854 [INFO]    ✅ Text body found (1760 chars).
# /var/folders/yz/8r0z_z0n0fn9g9n65xg0r4kh0000gn/T/ipykernel_43335/2125637373.py:67: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(raw_string, "html.parser")
# 2025-12-23 20:39:07,855 [INFO]    ☑️ Title found: 'Madison Keys vs. Olga Danilovi...'
# 2025-12-23 20:39:07,855 [INFO]    ☑️ Publish Date found: 2025-07-02T07:30:54.528Z
# 2025-12-23 20:39:07,856 [INFO]    ☑️ First Publish Date found: 2025-07-02T07:30:00Z
# 2025-12-23 20:39:07,856 [INFO]    ☑️ Datetime found: 2025-10-23T02:25:50.959Z
# 2025-12-23 20:39:07,857 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,857 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,857 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,857 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,857 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,858 [INFO]    🎉 Document 3D7QNFCLPZDJNFQD7JWNZX7NH4 successfully transformed.
# 2025-12-23 20:39:07,858 [INFO] 📄 Processing Document ID: 2FSDVCMJYZDULBQCHOF3SF7CSE
# 2025-12-23 20:39:07,858 [INFO]    ✅ URL found: https://www.nj.com/advice/2025/07/dear-abby-how-do-i-tell-the-man-of-my-dreams-hes-not-measuring-up-in-one-particular-way.html
# 2025-12-23 20:39:07,858 [INFO]    ✅ Text body found (1165 chars).
# 2025-12-23 20:39:07,858 [INFO]    ☑️ Title found: 'Dear Abby: How do I tell the m...'
# 2025-12-23 20:39:07,858 [INFO]    ☑️ Publish Date found: 2025-07-02T08:00:00Z
# 2025-12-23 20:39:07,859 [INFO]    ☑️ First Publish Date found: 2025-07-02T08:00:00Z
# 2025-12-23 20:39:07,859 [INFO]    ☑️ Datetime found: 2025-07-02T08:00:38.374Z
# 2025-12-23 20:39:07,859 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,859 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,859 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,859 [INFO]    ☑️ Categories found: 4 items
# 2025-12-23 20:39:07,860 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,860 [INFO]    🎉 Document 2FSDVCMJYZDULBQCHOF3SF7CSE successfully transformed.
# 2025-12-23 20:39:07,860 [INFO] 📄 Processing Document ID: 552STPGVMNAOXCHXAXA6XHK6GA
# 2025-12-23 20:39:07,860 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-homes-sold-in-lakewood-area-june-23-to-june-29.html
# 2025-12-23 20:39:07,860 [INFO]    ✅ Text body found (464 chars).
# 2025-12-23 20:39:07,860 [INFO]    ☑️ Title found: 'See homes sold in Lakewood are...'
# 2025-12-23 20:39:07,860 [INFO]    ☑️ Publish Date found: 2025-07-02T08:08:01.895Z
# 2025-12-23 20:39:07,861 [INFO]    ☑️ First Publish Date found: 2025-07-02T08:08:01.895Z
# 2025-12-23 20:39:07,861 [INFO]    ☑️ Datetime found: 2025-07-02T08:08:20.129Z
# 2025-12-23 20:39:07,861 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,861 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,862 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,862 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,862 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,862 [INFO]    🎉 Document 552STPGVMNAOXCHXAXA6XHK6GA successfully transformed.
# 2025-12-23 20:39:07,862 [INFO] 📄 Processing Document ID: G72554CBFBHZJKMKXWL3HSOX7M
# 2025-12-23 20:39:07,862 [INFO]    ✅ URL found: https://www.nj.com/sports/2025/07/amanda-anisimova-vs-renata-zarazua-7225-free-live-stream-watch-wimbledon-match-online-time-tv-channel.html
# 2025-12-23 20:39:07,871 [INFO]    ✅ Text body found (1771 chars).
# 2025-12-23 20:39:07,872 [INFO]    ☑️ Title found: 'Amanda Anisimova vs. Renata Za...'
# 2025-12-23 20:39:07,872 [INFO]    ☑️ Publish Date found: 2025-07-02T08:30:56.755Z
# 2025-12-23 20:39:07,873 [INFO]    ☑️ First Publish Date found: 2025-07-02T08:30:00Z
# 2025-12-23 20:39:07,873 [INFO]    ☑️ Datetime found: 2025-10-23T02:25:31.573Z
# 2025-12-23 20:39:07,874 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,874 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,874 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,875 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,875 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,875 [INFO]    🎉 Document G72554CBFBHZJKMKXWL3HSOX7M successfully transformed.
# 2025-12-23 20:39:07,875 [INFO] 📄 Processing Document ID: JGA2BIT64JEKZAK2R6BC47ULUE
# 2025-12-23 20:39:07,876 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-homes-sold-in-middletown-area-june-23-to-june-29.html
# 2025-12-23 20:39:07,876 [INFO]    ✅ Text body found (464 chars).
# 2025-12-23 20:39:07,876 [INFO]    ☑️ Title found: 'See homes sold in Middletown a...'
# 2025-12-23 20:39:07,876 [INFO]    ☑️ Publish Date found: 2025-07-02T08:48:02.04Z
# 2025-12-23 20:39:07,877 [INFO]    ☑️ First Publish Date found: 2025-07-02T08:48:02.04Z
# 2025-12-23 20:39:07,877 [INFO]    ☑️ Datetime found: 2025-07-02T08:48:21.125Z
# 2025-12-23 20:39:07,877 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,877 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,877 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,878 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,878 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,878 [INFO]    🎉 Document JGA2BIT64JEKZAK2R6BC47ULUE successfully transformed.
# 2025-12-23 20:39:07,878 [INFO] 📄 Processing Document ID: 5T2ASONNNFD7BP6K732PFG32CA
# 2025-12-23 20:39:07,878 [INFO]    ✅ URL found: https://www.nj.com/realestate-news/2025/07/see-all-homes-sold-in-mount-laurel-june-23-to-june-29.html
# 2025-12-23 20:39:07,878 [INFO]    ✅ Text body found (463 chars).
# 2025-12-23 20:39:07,879 [INFO]    ☑️ Title found: 'See all homes sold in Mount La...'
# 2025-12-23 20:39:07,879 [INFO]    ☑️ Publish Date found: 2025-07-02T08:58:01.73Z
# 2025-12-23 20:39:07,879 [INFO]    ☑️ First Publish Date found: 2025-07-02T08:58:01.73Z
# 2025-12-23 20:39:07,879 [INFO]    ☑️ Datetime found: 2025-07-02T08:58:20.234Z
# 2025-12-23 20:39:07,879 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,879 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,880 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,880 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,880 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,880 [INFO]    🎉 Document 5T2ASONNNFD7BP6K732PFG32CA successfully transformed.
# 2025-12-23 20:39:07,880 [INFO] 📄 Processing Document ID: GHKGSCEGUJHC7M2R2VLW6ZSIPA
# 2025-12-23 20:39:07,880 [INFO]    ✅ URL found: https://www.nj.com/sports/2025/07/frances-tiafoe-vs-cameron-norrie-7225-free-live-stream-watch-wimbledon-match-online-time-tv-channel.html
# 2025-12-23 20:39:07,890 [INFO]    ✅ Text body found (1764 chars).
# 2025-12-23 20:39:07,891 [INFO]    ☑️ Title found: 'Frances Tiafoe vs. Cameron Nor...'
# 2025-12-23 20:39:07,891 [INFO]    ☑️ Publish Date found: 2025-07-02T09:01:01.144Z
# 2025-12-23 20:39:07,891 [INFO]    ☑️ First Publish Date found: 2025-07-02T09:00:00Z
# 2025-12-23 20:39:07,892 [INFO]    ☑️ Datetime found: 2025-07-02T09:01:01.345Z
# 2025-12-23 20:39:07,892 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,892 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,892 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,892 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,893 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,893 [INFO]    🎉 Document GHKGSCEGUJHC7M2R2VLW6ZSIPA successfully transformed.
# 2025-12-23 20:39:07,893 [INFO] 📄 Processing Document ID: ETT37IIIUFHZFP7C3EE6IQQ7YE
# 2025-12-23 20:39:07,893 [INFO]    ✅ URL found: https://www.nj.com/entertainment/2025/07/we-dont-want-our-music-killing-people-popular-rock-band-says-denouncing-streaming-service.html
# 2025-12-23 20:39:07,894 [INFO]    ✅ Text body found (2663 chars).
# 2025-12-23 20:39:07,894 [INFO]    ☑️ Title found: '‘We don’t want our music killi...'
# 2025-12-23 20:39:07,895 [INFO]    ☑️ Publish Date found: 2025-07-11T04:09:52.27Z
# 2025-12-23 20:39:07,895 [INFO]    ☑️ First Publish Date found: 2025-07-02T09:00:00Z
# 2025-12-23 20:39:07,895 [INFO]    ☑️ Datetime found: 2025-07-11T04:09:52.4Z
# 2025-12-23 20:39:07,895 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,895 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,896 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,896 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,896 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,896 [INFO]    🎉 Document ETT37IIIUFHZFP7C3EE6IQQ7YE successfully transformed.
# 2025-12-23 20:39:07,896 [INFO] 📄 Processing Document ID: VM6GGVBC6RGXTALNHQQT4F4HXM
# 2025-12-23 20:39:07,896 [INFO]    ✅ URL found: https://www.nj.com/sports/2025/07/aryna-sabalenka-vs-marie-bouzkova-7225-free-live-stream-watch-wimbledon-match-online-time-tv-channel.html
# 2025-12-23 20:39:07,907 [INFO]    ✅ Text body found (1817 chars).
# 2025-12-23 20:39:07,907 [INFO]    ☑️ Title found: 'Aryna Sabalenka vs. Marie Bouz...'
# 2025-12-23 20:39:07,908 [INFO]    ☑️ Publish Date found: 2025-07-02T09:30:53.411Z
# 2025-12-23 20:39:07,908 [INFO]    ☑️ First Publish Date found: 2025-07-02T09:30:00Z
# 2025-12-23 20:39:07,908 [INFO]    ☑️ Datetime found: 2025-10-23T02:24:53.445Z
# 2025-12-23 20:39:07,909 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,909 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,909 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,909 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,909 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,910 [INFO]    🎉 Document VM6GGVBC6RGXTALNHQQT4F4HXM successfully transformed.
# 2025-12-23 20:39:07,910 [INFO] 📄 Processing Document ID: XKNK7K5YNRGFBCWXCGPX3J35PM
# 2025-12-23 20:39:07,910 [INFO]    ✅ URL found: https://www.nj.com/advice/2025/07/miss-manners-cousin-who-gives-vague-responses-should-get-vague-responses.html
# 2025-12-23 20:39:07,910 [INFO]    ✅ Text body found (1232 chars).
# 2025-12-23 20:39:07,910 [INFO]    ☑️ Title found: 'Miss Manners: Cousin who gives...'
# 2025-12-23 20:39:07,910 [INFO]    ☑️ Publish Date found: 2025-07-02T10:00:00Z
# 2025-12-23 20:39:07,911 [INFO]    ☑️ First Publish Date found: 2025-07-02T10:00:00Z
# 2025-12-23 20:39:07,911 [INFO]    ☑️ Datetime found: 2025-07-02T10:00:24.677Z
# 2025-12-23 20:39:07,911 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,911 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,911 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,911 [INFO]    ☑️ Categories found: 1 items
# 2025-12-23 20:39:07,911 [INFO]    ☑️ Tags found: 2 items
# 2025-12-23 20:39:07,912 [INFO]    🎉 Document XKNK7K5YNRGFBCWXCGPX3J35PM successfully transformed.
# 2025-12-23 20:39:07,912 [INFO] 📄 Processing Document ID: PGHPSYPEWBF6ZC652YLIMNNE4E
# 2025-12-23 20:39:07,912 [INFO]    ✅ URL found: https://www.nj.com/yankees/2025/07/yankees-on-verge-of-switcheroo-eugenio-suarez-on-radar-analysis.html
# 2025-12-23 20:39:07,915 [INFO]    ✅ Text body found (6414 chars).
# 2025-12-23 20:39:07,916 [INFO]    ☑️ Title found: 'Yankees on verge of switcheroo...'
# 2025-12-23 20:39:07,916 [INFO]    ☑️ Publish Date found: 2025-07-02T10:01:03.62Z
# 2025-12-23 20:39:07,916 [INFO]    ☑️ First Publish Date found: 2025-07-02T10:00:00Z
# 2025-12-23 20:39:07,916 [INFO]    ☑️ Datetime found: 2025-07-02T10:02:10.425Z
# 2025-12-23 20:39:07,916 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,916 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,917 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,917 [INFO]    ☑️ Categories found: 4 items
# 2025-12-23 20:39:07,917 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,917 [INFO]    🎉 Document PGHPSYPEWBF6ZC652YLIMNNE4E successfully transformed.
# 2025-12-23 20:39:07,917 [INFO] 📄 Processing Document ID: IATLFPXSUZDNTF6LQ5QF4BGUH4
# 2025-12-23 20:39:07,917 [INFO]    ✅ URL found: https://www.nj.com/eagles/2025/07/why-phillies-legend-was-pulled-over-by-police-32-years-ago-after-his-hit-ended-game-at-440-am.html
# 2025-12-23 20:39:07,920 [INFO]    ✅ Text body found (7373 chars).
# 2025-12-23 20:39:07,921 [INFO]    ☑️ Title found: 'Why Phillies legend was stoppe...'
# 2025-12-23 20:39:07,921 [INFO]    ☑️ Publish Date found: 2025-07-04T19:11:44.166Z
# 2025-12-23 20:39:07,921 [INFO]    ☑️ First Publish Date found: 2025-07-02T10:00:01Z
# 2025-12-23 20:39:07,921 [INFO]    ☑️ Datetime found: 2025-07-04T19:11:44.356Z
# 2025-12-23 20:39:07,921 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,921 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,922 [INFO]    ☑️ Sections found: 6 items
# 2025-12-23 20:39:07,922 [INFO]    ⚪ Categories empty.
# 2025-12-23 20:39:07,922 [INFO]    ☑️ Tags found: 2 items
# 2025-12-23 20:39:07,922 [INFO]    🎉 Document IATLFPXSUZDNTF6LQ5QF4BGUH4 successfully transformed.
# 2025-12-23 20:39:07,922 [INFO] 📄 Processing Document ID: 5S2UHG6RV5G2JOJQPRUIXM7LAU
# 2025-12-23 20:39:07,922 [INFO]    ✅ URL found: https://www.nj.com/mets/2025/07/mets-starter-who-suffered-devastating-injury-seeks-help-of-nba-star.html
# 2025-12-23 20:39:07,924 [INFO]    ✅ Text body found (2033 chars).
# 2025-12-23 20:39:07,925 [INFO]    ☑️ Title found: 'Mets starter who suffered deva...'
# 2025-12-23 20:39:07,925 [INFO]    ☑️ Publish Date found: 2025-07-02T15:05:41.824Z
# 2025-12-23 20:39:07,925 [INFO]    ☑️ First Publish Date found: 2025-07-02T10:00:01Z
# 2025-12-23 20:39:07,925 [INFO]    ☑️ Datetime found: 2025-07-02T15:05:41.939Z
# 2025-12-23 20:39:07,925 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,925 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,925 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,926 [INFO]    ⚪ Categories empty.
# 2025-12-23 20:39:07,926 [INFO]    ☑️ Tags found: 1 items
# 2025-12-23 20:39:07,926 [INFO]    🎉 Document 5S2UHG6RV5G2JOJQPRUIXM7LAU successfully transformed.
# 2025-12-23 20:39:07,926 [INFO] 📄 Processing Document ID: 5TFPVIRYT5BOXMC6JRQXGYF26Y
# 2025-12-23 20:39:07,926 [INFO]    ✅ URL found: https://www.nj.com/yankees/2025/07/is-george-lombard-jr-or-anthony-volpe-yankees-future-at-short-scout-has-strong-opinion.html
# 2025-12-23 20:39:07,933 [INFO]    ✅ Text body found (7631 chars).
# 2025-12-23 20:39:07,934 [INFO]    ☑️ Title found: 'Is George Lombard Jr. or Antho...'
# 2025-12-23 20:39:07,934 [INFO]    ☑️ Publish Date found: 2025-07-03T13:10:26.442Z
# 2025-12-23 20:39:07,934 [INFO]    ☑️ First Publish Date found: 2025-07-02T10:10:00Z
# 2025-12-23 20:39:07,934 [INFO]    ☑️ Datetime found: 2025-07-03T13:10:26.644Z
# 2025-12-23 20:39:07,934 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,934 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,935 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,935 [INFO]    ☑️ Categories found: 2 items
# 2025-12-23 20:39:07,935 [INFO]    ☑️ Tags found: 1 items
# 2025-12-23 20:39:07,935 [INFO]    🎉 Document 5TFPVIRYT5BOXMC6JRQXGYF26Y successfully transformed.
# 2025-12-23 20:39:07,935 [INFO] 📄 Processing Document ID: XNFID4CCL5E5LMJDBYJQJMBRCM
# 2025-12-23 20:39:07,935 [INFO]    ✅ URL found: https://www.nj.com/news/2025/07/todays-audio-update-netflixs-new-studio-and-jersey-shore-property-expected-to-become-a-park.html
# 2025-12-23 20:39:07,936 [INFO]    ✅ Text body found (653 chars).
# 2025-12-23 20:39:07,936 [INFO]    ☑️ Title found: 'Today’s audio update: Netflix’...'
# 2025-12-23 20:39:07,936 [INFO]    ☑️ Publish Date found: 2025-07-02T10:30:57.992Z
# 2025-12-23 20:39:07,936 [INFO]    ☑️ First Publish Date found: 2025-07-02T10:30:00Z
# 2025-12-23 20:39:07,936 [INFO]    ☑️ Datetime found: 2025-07-02T10:30:58.083Z
# 2025-12-23 20:39:07,936 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,937 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,937 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,937 [INFO]    ☑️ Categories found: 1 items
# 2025-12-23 20:39:07,937 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,937 [INFO]    🎉 Document XNFID4CCL5E5LMJDBYJQJMBRCM successfully transformed.
# 2025-12-23 20:39:07,937 [INFO] 📄 Processing Document ID: IVTCH3JH4BBZNCDIK4AFDJCAYE
# 2025-12-23 20:39:07,937 [INFO]    ✅ URL found: https://www.nj.com/sports/2025/07/carlos-alcaraz-vs-oliver-tarvet-7225-free-live-stream-watch-wimbledon-match-online-time-tv-channel.html
# 2025-12-23 20:39:07,947 [INFO]    ✅ Text body found (1805 chars).
# 2025-12-23 20:39:07,947 [INFO]    ☑️ Title found: 'Carlos Alcaraz vs. Oliver Tarv...'
# 2025-12-23 20:39:07,947 [INFO]    ☑️ Publish Date found: 2025-07-02T10:40:51.828Z
# 2025-12-23 20:39:07,948 [INFO]    ☑️ First Publish Date found: 2025-07-02T10:40:00Z
# 2025-12-23 20:39:07,948 [INFO]    ☑️ Datetime found: 2025-10-23T02:24:33.725Z
# 2025-12-23 20:39:07,948 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,948 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,948 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:07,948 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,948 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,949 [INFO]    🎉 Document IVTCH3JH4BBZNCDIK4AFDJCAYE successfully transformed.
# 2025-12-23 20:39:07,949 [INFO] 📄 Processing Document ID: CUHYPZH77BGCXPI2SSJDOVNQLY
# 2025-12-23 20:39:07,949 [INFO]    ✅ URL found: https://www.nj.com/rutgersfootball/2025/07/rutgers-football-signs-multiple-assistant-coaches-to-contract-extensions-heading-into-2025-season.html
# 2025-12-23 20:39:07,951 [INFO]    ✅ Text body found (2933 chars).
# 2025-12-23 20:39:07,951 [INFO]    ☑️ Title found: 'Rutgers football signs multipl...'
# 2025-12-23 20:39:07,952 [INFO]    ☑️ Publish Date found: 2025-07-02T10:52:15.365Z
# 2025-12-23 20:39:07,952 [INFO]    ☑️ First Publish Date found: 2025-07-02T10:40:00Z
# 2025-12-23 20:39:07,952 [INFO]    ☑️ Datetime found: 2025-07-02T10:52:15.365Z
# 2025-12-23 20:39:07,952 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,953 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,953 [INFO]    ☑️ Sections found: 3 items
# 2025-12-23 20:39:07,953 [INFO]    ☑️ Categories found: 3 items
# 2025-12-23 20:39:07,953 [INFO]    ☑️ Tags found: 3 items
# 2025-12-23 20:39:07,953 [INFO]    🎉 Document CUHYPZH77BGCXPI2SSJDOVNQLY successfully transformed.
# 2025-12-23 20:39:07,953 [INFO] 📄 Processing Document ID: WHQULF4Z6NGP3GCSIOSUVSNOYE
# 2025-12-23 20:39:07,953 [INFO]    ✅ URL found: https://www.nj.com/sports/2025/07/damian-lillards-next-team-odds-point-to-one-team-above-the-rest.html
# 2025-12-23 20:39:07,954 [INFO]    ✅ Text body found (629 chars).
# 2025-12-23 20:39:07,954 [INFO]    ☑️ Title found: 'Damian Lillard’s next team? Od...'
# 2025-12-23 20:39:07,954 [INFO]    ☑️ Publish Date found: 2025-07-02T11:25:20.851Z
# 2025-12-23 20:39:07,954 [INFO]    ☑️ First Publish Date found: 2025-07-02T10:45:26.138Z
# 2025-12-23 20:39:07,954 [INFO]    ☑️ Datetime found: 2025-07-02T11:25:20.961Z
# 2025-12-23 20:39:07,954 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,955 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,955 [INFO]    ☑️ Sections found: 4 items
# 2025-12-23 20:39:07,955 [INFO]    ⚪ Categories empty.
# 2025-12-23 20:39:07,955 [INFO]    ☑️ Tags found: 3 items
# 2025-12-23 20:39:07,955 [INFO]    🎉 Document WHQULF4Z6NGP3GCSIOSUVSNOYE successfully transformed.
# 2025-12-23 20:39:07,955 [INFO] 📄 Processing Document ID: DCS57SUXQZDSTFC3KTP47QO47U
# 2025-12-23 20:39:07,955 [INFO]    ✅ URL found: https://www.nj.com/advice/2025/07/asking-eric-i-try-to-see-my-daughters-husband-as-she-does-but-hes-just-not-good-enough-for-her.html
# 2025-12-23 20:39:07,956 [INFO]    ✅ Text body found (3737 chars).
# 2025-12-23 20:39:07,956 [INFO]    ☑️ Title found: 'Asking Eric: I try to see my d...'
# 2025-12-23 20:39:07,956 [INFO]    ☑️ Publish Date found: 2025-07-02T11:00:00Z
# 2025-12-23 20:39:07,956 [INFO]    ☑️ First Publish Date found: 2025-07-02T11:00:00Z
# 2025-12-23 20:39:07,957 [INFO]    ☑️ Datetime found: 2025-07-02T11:00:47.072Z
# 2025-12-23 20:39:07,957 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,957 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,957 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,957 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,958 [INFO]    ☑️ Tags found: 3 items
# 2025-12-23 20:39:07,958 [INFO]    🎉 Document DCS57SUXQZDSTFC3KTP47QO47U successfully transformed.
# 2025-12-23 20:39:07,958 [INFO] 📄 Processing Document ID: YJ4NCL4TN5A5JBIGZCHMRKK4R4
# 2025-12-23 20:39:07,958 [INFO]    ✅ URL found: https://www.nj.com/phillies/2025/07/will-phillies-zack-wheeler-start-the-all-star-game-in-his-hometown-of-atlanta.html
# 2025-12-23 20:39:07,959 [INFO]    ✅ Text body found (2733 chars).
# 2025-12-23 20:39:07,959 [INFO]    ☑️ Title found: 'Will Phillies’ Zack Wheeler st...'
# 2025-12-23 20:39:07,959 [INFO]    ☑️ Publish Date found: 2025-07-02T11:01:00Z
# 2025-12-23 20:39:07,960 [INFO]    ☑️ First Publish Date found: 2025-07-02T11:01:00Z
# 2025-12-23 20:39:07,960 [INFO]    ☑️ Datetime found: 2025-07-02T11:01:32.949Z
# 2025-12-23 20:39:07,960 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,960 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,960 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,960 [INFO]    ☑️ Categories found: 4 items
# 2025-12-23 20:39:07,961 [INFO]    ⚪ Tags empty.
# 2025-12-23 20:39:07,961 [INFO]    🎉 Document YJ4NCL4TN5A5JBIGZCHMRKK4R4 successfully transformed.
# 2025-12-23 20:39:07,961 [INFO] 📄 Processing Document ID: 5QVHU5YKHVCUFL5G2L7QIYSYTY
# 2025-12-23 20:39:07,961 [INFO]    ✅ URL found: https://www.nj.com/education/2025/07/the-5-biggest-perks-in-new-rutgers-presidents-record-breaking-contract.html
# 2025-12-23 20:39:07,963 [INFO]    ✅ Text body found (3947 chars).
# 2025-12-23 20:39:07,964 [INFO]    ☑️ Title found: 'The 5 biggest perks in new Rut...'
# 2025-12-23 20:39:07,964 [INFO]    ☑️ Publish Date found: 2025-07-04T04:10:24.26Z
# 2025-12-23 20:39:07,964 [INFO]    ☑️ First Publish Date found: 2025-07-02T11:01:00Z
# 2025-12-23 20:39:07,964 [INFO]    ☑️ Datetime found: 2025-07-04T04:10:24.438Z
# 2025-12-23 20:39:07,964 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,965 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,983 [INFO]    ☑️ Sections found: 3 items
# 2025-12-23 20:39:07,983 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,983 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,984 [INFO]    🎉 Document 5QVHU5YKHVCUFL5G2L7QIYSYTY successfully transformed.
# 2025-12-23 20:39:07,984 [INFO] 📄 Processing Document ID: KNQJREAL2JBJFGZHQRRYCLFDOM
# 2025-12-23 20:39:07,984 [INFO]    ✅ URL found: https://www.nj.com/gloucester-county/2025/07/5-lined-skink-is-njs-only-native-lizard-found-statewidegloucester-county-nature-club.html
# 2025-12-23 20:39:07,984 [INFO]    ✅ Text body found (2745 chars).
# 2025-12-23 20:39:07,985 [INFO]    ☑️ Title found: '5-lined skink is N.J.’s only n...'
# 2025-12-23 20:39:07,985 [INFO]    ☑️ Publish Date found: 2025-07-02T11:03:14.358Z
# 2025-12-23 20:39:07,985 [INFO]    ☑️ First Publish Date found: 2025-07-02T11:02:19.252Z
# 2025-12-23 20:39:07,985 [INFO]    ☑️ Datetime found: 2025-07-02T11:03:14.514Z
# 2025-12-23 20:39:07,985 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,985 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,985 [INFO]    ☑️ Sections found: 3 items
# 2025-12-23 20:39:07,986 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,986 [INFO]    ☑️ Tags found: 3 items
# 2025-12-23 20:39:07,986 [INFO]    🎉 Document KNQJREAL2JBJFGZHQRRYCLFDOM successfully transformed.
# 2025-12-23 20:39:07,986 [INFO] 📄 Processing Document ID: YG3YF6F5H5HKLBSKFA76BOIXHQ
# 2025-12-23 20:39:07,986 [INFO]    ✅ URL found: https://www.nj.com/news/2025/07/nj-fireworks-2025-fourth-of-july-4th-list-of-parades-concerts-events.html
# 2025-12-23 20:39:07,987 [INFO]    ✅ Text body found (1005 chars).
# 2025-12-23 20:39:07,987 [INFO]    ☑️ Title found: 'N.J. fireworks 2025 Fourth of ...'
# 2025-12-23 20:39:07,987 [INFO]    ☑️ Publish Date found: 2025-07-03T15:27:49.277Z
# 2025-12-23 20:39:07,987 [INFO]    ☑️ First Publish Date found: 2025-07-02T11:16:00Z
# 2025-12-23 20:39:07,987 [INFO]    ☑️ Datetime found: 2025-07-03T15:27:49.545Z
# 2025-12-23 20:39:07,987 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,988 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,988 [INFO]    ☑️ Sections found: 22 items
# 2025-12-23 20:39:07,988 [INFO]    ☑️ Categories found: 4 items
# 2025-12-23 20:39:07,988 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,988 [INFO]    🎉 Document YG3YF6F5H5HKLBSKFA76BOIXHQ successfully transformed.
# 2025-12-23 20:39:07,988 [INFO] 📄 Processing Document ID: 4DBOQLVRS5CM7ODP2KOC3H4B3Q
# 2025-12-23 20:39:07,988 [INFO]    ✅ URL found: https://www.nj.com/rutgersbasketball/2025/07/spurs-envision-ex-rutgers-star-as-part-of-new-big-3-to-challenge-nba-champs.html
# 2025-12-23 20:39:07,990 [INFO]    ✅ Text body found (3177 chars).
# 2025-12-23 20:39:07,990 [INFO]    ☑️ Title found: 'Spurs envision ex-Rutgers star...'
# 2025-12-23 20:39:07,990 [INFO]    ☑️ Publish Date found: 2025-07-02T15:19:54.091Z
# 2025-12-23 20:39:07,991 [INFO]    ☑️ First Publish Date found: 2025-07-02T11:24:08.701Z
# 2025-12-23 20:39:07,991 [INFO]    ☑️ Datetime found: 2025-07-02T15:19:54.186Z
# 2025-12-23 20:39:07,991 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,991 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,991 [INFO]    ☑️ Sections found: 5 items
# 2025-12-23 20:39:07,991 [INFO]    ⚪ Categories empty.
# 2025-12-23 20:39:07,992 [INFO]    ⚪ Tags empty.
# 2025-12-23 20:39:07,992 [INFO]    🎉 Document 4DBOQLVRS5CM7ODP2KOC3H4B3Q successfully transformed.
# 2025-12-23 20:39:07,992 [INFO] 📄 Processing Document ID: GQF2XBCNO5EJ7OUJ44PITEKHK4
# 2025-12-23 20:39:07,992 [INFO]    ✅ URL found: https://www.nj.com/news/2025/07/why-80-people-were-firing-shotguns-off-njs-most-famous-warship-last-week.html
# 2025-12-23 20:39:07,993 [INFO]    ✅ Text body found (2982 chars).
# 2025-12-23 20:39:07,993 [INFO]    ☑️ Title found: 'Why 80 people were firing shot...'
# 2025-12-23 20:39:07,993 [INFO]    ☑️ Publish Date found: 2025-07-02T11:26:06.169Z
# 2025-12-23 20:39:07,994 [INFO]    ☑️ First Publish Date found: 2025-07-02T11:25:00Z
# 2025-12-23 20:39:07,994 [INFO]    ☑️ Datetime found: 2025-07-02T11:26:06.295Z
# 2025-12-23 20:39:07,994 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,994 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,994 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,994 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:07,995 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:07,995 [INFO]    🎉 Document GQF2XBCNO5EJ7OUJ44PITEKHK4 successfully transformed.
# 2025-12-23 20:39:07,995 [INFO] 📄 Processing Document ID: 7QIETJFELBDVPFFJJSRVXQ6GLA
# 2025-12-23 20:39:07,995 [INFO]    ✅ URL found: https://www.nj.com/weather/2025/07/nj-weather-rain-thunderstorms-likely-today-thursday-early-july-4th-forecast.html
# 2025-12-23 20:39:07,995 [INFO]    ✅ Text body found (1969 chars).
# 2025-12-23 20:39:07,996 [INFO]    ☑️ Title found: 'N.J. weather: Rain, thundersto...'
# 2025-12-23 20:39:07,996 [INFO]    ☑️ Publish Date found: 2025-07-02T11:32:54.124Z
# 2025-12-23 20:39:07,996 [INFO]    ☑️ First Publish Date found: 2025-07-02T11:26:03.161Z
# 2025-12-23 20:39:07,996 [INFO]    ☑️ Datetime found: 2025-07-02T11:32:54.228Z
# 2025-12-23 20:39:07,996 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:07,996 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:07,996 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:07,997 [INFO]    ⚪ Categories empty.
# 2025-12-23 20:39:07,997 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:07,997 [INFO]    🎉 Document 7QIETJFELBDVPFFJJSRVXQ6GLA successfully transformed.
# 2025-12-23 20:39:07,997 [INFO] 📄 Processing Document ID: VKAGZ3WZ7NFJPEOATVA2RTM7RU
# 2025-12-23 20:39:07,997 [INFO]    ✅ URL found: https://www.nj.com/politics/2025/07/see-who-has-a-big-early-lead-in-first-poll-of-njs-ciattarelli-vs-sherrill-governors-race.html
# 🚀 Starting ingestion of 50 documents...
# 2025-12-23 20:39:08,002 [INFO]    ✅ Text body found (4682 chars).
# 2025-12-23 20:39:08,002 [INFO]    ☑️ Title found: 'See who has a big early lead i...'
# 2025-12-23 20:39:08,003 [INFO]    ☑️ Publish Date found: 2025-07-07T00:50:05.401Z
# 2025-12-23 20:39:08,003 [INFO]    ☑️ First Publish Date found: 2025-07-02T11:30:00Z
# 2025-12-23 20:39:08,003 [INFO]    ☑️ Datetime found: 2025-07-07T00:50:05.569Z
# 2025-12-23 20:39:08,003 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:08,003 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:08,003 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:08,004 [INFO]    ☑️ Categories found: 4 items
# 2025-12-23 20:39:08,004 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:08,004 [INFO]    🎉 Document VKAGZ3WZ7NFJPEOATVA2RTM7RU successfully transformed.
# 2025-12-23 20:39:08,004 [INFO] 📄 Processing Document ID: 2KGLAIGGY5EXLOVQGIRM4XTLXU
# 2025-12-23 20:39:08,004 [INFO]    ✅ URL found: https://www.nj.com/entertainment/2025/07/has-asbury-park-already-peaked-a-deep-dive-into-jerseys-hottest-shore-town.html
# 2025-12-23 20:39:08,009 [INFO]    ✅ Text body found (3103 chars).
# 2025-12-23 20:39:08,010 [INFO]    ☑️ Title found: 'Has Asbury Park already peaked...'
# 2025-12-23 20:39:08,010 [INFO]    ☑️ Publish Date found: 2025-07-02T18:29:34.945Z
# 2025-12-23 20:39:08,010 [INFO]    ☑️ First Publish Date found: 2025-07-02T12:00:00Z
# 2025-12-23 20:39:08,010 [INFO]    ☑️ Datetime found: 2025-07-02T18:29:35.045Z
# 2025-12-23 20:39:08,010 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:08,010 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:08,010 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:08,010 [INFO]    ☑️ Categories found: 2 items
# 2025-12-23 20:39:08,011 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:08,011 [INFO]    🎉 Document 2KGLAIGGY5EXLOVQGIRM4XTLXU successfully transformed.
# 2025-12-23 20:39:08,011 [INFO] 📄 Processing Document ID: V4T3YI43TFA4FOPVLABJS3VLLU
# 2025-12-23 20:39:08,011 [INFO]    ✅ URL found: https://www.nj.com/sports/2025/07/taylor-fritz-vs-gabriel-diallo-7225-free-live-stream-watch-wimbledon-match-online-time-tv-channel.html
# 2025-12-23 20:39:08,021 [INFO]    ✅ Text body found (1764 chars).
# 2025-12-23 20:39:08,022 [INFO]    ☑️ Title found: 'Taylor Fritz vs. Gabriel Diall...'
# 2025-12-23 20:39:08,022 [INFO]    ☑️ Publish Date found: 2025-07-02T12:01:52.691Z
# 2025-12-23 20:39:08,022 [INFO]    ☑️ First Publish Date found: 2025-07-02T12:00:00Z
# 2025-12-23 20:39:08,022 [INFO]    ☑️ Datetime found: 2025-10-23T02:24:15.253Z
# 2025-12-23 20:39:08,022 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:08,022 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:08,023 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:08,023 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:08,023 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:08,023 [INFO]    🎉 Document V4T3YI43TFA4FOPVLABJS3VLLU successfully transformed.
# 2025-12-23 20:39:08,023 [INFO] 📄 Processing Document ID: WE5GROXSHVAXPO6ZAOYMV65KDY
# 2025-12-23 20:39:08,023 [INFO]    ✅ URL found: https://www.nj.com/business/2025/07/what-is-open-on-july-4th-see-all-open-stores-services-and-more-on-the-4th-of-july.html
# 2025-12-23 20:39:08,030 [INFO]    ✅ Text body found (4082 chars).
# 2025-12-23 20:39:08,030 [INFO]    ☑️ Title found: 'What is open on July 4th? See ...'
# 2025-12-23 20:39:08,030 [INFO]    ☑️ Publish Date found: 2025-07-02T13:45:08.066Z
# 2025-12-23 20:39:08,031 [INFO]    ☑️ First Publish Date found: 2025-07-02T12:00:00Z
# 2025-12-23 20:39:08,031 [INFO]    ☑️ Datetime found: 2025-07-02T13:45:08.066Z
# 2025-12-23 20:39:08,031 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:08,031 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:08,032 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:08,032 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:08,032 [INFO]    ☑️ Tags found: 4 items
# 2025-12-23 20:39:08,032 [INFO]    🎉 Document WE5GROXSHVAXPO6ZAOYMV65KDY successfully transformed.
# 2025-12-23 20:39:08,032 [INFO] 📄 Processing Document ID: PCNAP7EAAVEONL4KROK3R574C4
# 2025-12-23 20:39:08,032 [INFO]    ✅ URL found: https://www.nj.com/advice/2025/07/july-2-birthday-horoscope-and-your-daily-astrology.html
# 2025-12-23 20:39:08,034 [INFO]    ✅ Text body found (4593 chars).
# 2025-12-23 20:39:08,035 [INFO]    ☑️ Title found: 'July 2 birthday horoscope and ...'
# 2025-12-23 20:39:08,035 [INFO]    ☑️ Publish Date found: 2025-07-02T12:00:00Z
# 2025-12-23 20:39:08,035 [INFO]    ☑️ First Publish Date found: 2025-07-02T12:00:00Z
# 2025-12-23 20:39:08,035 [INFO]    ☑️ Datetime found: 2025-07-02T12:00:38.992Z
# 2025-12-23 20:39:08,035 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:08,036 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:08,036 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:08,036 [INFO]    ☑️ Categories found: 4 items
# 2025-12-23 20:39:08,036 [INFO]    ☑️ Tags found: 3 items
# 2025-12-23 20:39:08,036 [INFO]    🎉 Document PCNAP7EAAVEONL4KROK3R574C4 successfully transformed.
# 2025-12-23 20:39:08,037 [INFO] 📄 Processing Document ID: BPU74ZWZK5DBNORLVSF7FWROZU
# 2025-12-23 20:39:08,037 [INFO]    ✅ URL found: https://www.nj.com/mosaic/2025/07/why-experts-fear-the-drop-in-nj-gun-violence-could-reverse-this-summer.html
# 2025-12-23 20:39:08,045 [INFO]    ✅ Text body found (9148 chars).
# 2025-12-23 20:39:08,045 [INFO]    ☑️ Title found: 'Why experts fear the drop in N...'
# 2025-12-23 20:39:08,046 [INFO]    ☑️ Publish Date found: 2025-07-02T12:55:11.551Z
# 2025-12-23 20:39:08,046 [INFO]    ☑️ First Publish Date found: 2025-07-02T12:15:52.199Z
# 2025-12-23 20:39:08,046 [INFO]    ☑️ Datetime found: 2025-07-02T12:55:12.034Z
# 2025-12-23 20:39:08,046 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:08,046 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:08,046 [INFO]    ☑️ Sections found: 1 items
# 2025-12-23 20:39:08,047 [INFO]    ☑️ Categories found: 5 items
# 2025-12-23 20:39:08,047 [INFO]    ☑️ Tags found: 5 items
# 2025-12-23 20:39:08,047 [INFO]    🎉 Document BPU74ZWZK5DBNORLVSF7FWROZU successfully transformed.
# 2025-12-23 20:39:08,047 [INFO] 📄 Processing Document ID: 7VQXMIUFSFBY7KTUJTBBEFOPIQ
# 2025-12-23 20:39:08,047 [INFO]    ✅ URL found: https://www.nj.com/news/2025/07/bus-crash-injures-12-shuts-down-ny-bus-terminal-during-morning-rush.html
# 2025-12-23 20:39:08,048 [INFO]    ✅ Text body found (1628 chars).
# 2025-12-23 20:39:08,048 [INFO]    ☑️ Title found: 'Bus crash injures 17, closes p...'
# 2025-12-23 20:39:08,048 [INFO]    ☑️ Publish Date found: 2025-07-02T16:57:08.364Z
# 2025-12-23 20:39:08,048 [INFO]    ☑️ First Publish Date found: 2025-07-02T12:30:43.206Z
# 2025-12-23 20:39:08,048 [INFO]    ☑️ Datetime found: 2025-07-02T16:57:08.52Z
# 2025-12-23 20:39:08,048 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:08,048 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:08,049 [INFO]    ☑️ Sections found: 2 items
# 2025-12-23 20:39:08,049 [INFO]    ☑️ Categories found: 3 items
# 2025-12-23 20:39:08,049 [INFO]    ☑️ Tags found: 2 items
# 2025-12-23 20:39:08,049 [INFO]    🎉 Document 7VQXMIUFSFBY7KTUJTBBEFOPIQ successfully transformed.
# 2025-12-23 20:39:08,049 [INFO] 📄 Processing Document ID: 5KRZIWXTEFB6NIJKG6XQV7BUV4
# 2025-12-23 20:39:08,049 [INFO]    ✅ URL found: https://www.nj.com/weather/2025/07/nj-weather-5-inches-of-rain-fell-overnight-see-how-much-rain-your-town-got.html
# 2025-12-23 20:39:08,073 [INFO]    ✅ Text body found (1176 chars).
# 2025-12-23 20:39:08,073 [INFO]    ☑️ Title found: 'N.J. weather: 5+ inches of rai...'
# 2025-12-23 20:39:08,073 [INFO]    ☑️ Publish Date found: 2025-07-03T19:11:53.392Z
# 2025-12-23 20:39:08,073 [INFO]    ☑️ First Publish Date found: 2025-07-02T12:57:49.485Z
# 2025-12-23 20:39:08,073 [INFO]    ☑️ Datetime found: 2025-07-03T19:11:53.546Z
# 2025-12-23 20:39:08,073 [INFO]    ☑️ Website found: nj
# 2025-12-23 20:39:08,074 [INFO]    ☑️ Thumbnail found.
# 2025-12-23 20:39:08,074 [INFO]    ☑️ Sections found: 4 items
# 2025-12-23 20:39:08,074 [INFO]    ☑️ Categories found: 4 items
# 2025-12-23 20:39:08,074 [INFO]    ☑️ Tags found: 2 items
# 2025-12-23 20:39:08,074 [INFO]    🎉 Document 5KRZIWXTEFB6NIJKG6XQV7BUV4 successfully transformed.
# ========================================
#  📊 PIPELINE HEALTH DASHBOARD
# ========================================
#  • Total Documents:   50
#  • Success Rate:      100.0%
#  • Failed/Skipped:    0
# ========================================
#
#
# ✅ Processing Complete!
#    - Total Input:      50
#    - Unique Success:   50 (Saved to processed_output_updated.json)
#    - Duplicates:       0 (Merged/Updated)
#    - Failures:         0 (Sent to Dead Letter Queue)
#    - Detailed Logs:    pipeline.log
#    - Summary Report:   ingestion_report.csv
